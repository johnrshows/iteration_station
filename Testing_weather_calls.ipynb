# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import scipy.stats as st
from pprint import pprint
import datetime

x = datetime.datetime.now()


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Marietta I-75
lat = 33.946706
lon = -84.513774


city = citipy.nearest_city(lat, lon).city_name
country = citipy.nearest_city(lat,lon).country_code

from datetime import timezone
starttime = datetime.datetime(2019, 5, 15)
start = starttime.replace(tzinfo=timezone.utc).timestamp()
endtime = datetime.datetime(2019, 5, 16)
end = endtime.replace(tzinfo=timezone.utc).timestamp()

print(start)
print(end)

print(city)
print(country)
# Out:
# 1557878400.0
# 1557964800.0
# marietta
# us

# %%
base_url = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx?"
date_q = "2019-03-22"
#using lat/long of Marietta as provided above
response = requests.get(f"{base_url}key={api_key}&q={lat},{lon}&format=json&date={date_q}").json()

response
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 33.95 and Lon -84.51'}],
#   'weather': [{'date': '2019-03-22',
#     'astronomy': [{'sunrise': '07:40 AM',
#       'sunset': '07:51 PM',
#       'moonrise': '09:54 PM',
#       'moonset': '08:57 AM',
#       'moon_phase': 'Waxing Gibbous',
#       'moon_illumination': '88'}],
#     'maxtempC': '17',
#     'maxtempF': '63',
#     'mintempC': '4',
#     'mintempF': '39',
#     'avgtempC': '11',
#     'avgtempF': '53',
#     'totalSnow_cm': '0.0',
#     'sunHour': '11.6',
#     'uvIndex': '4',
#     'hourly': [{'time': '0',
#       'tempC': '9',
#       'tempF': '49',
#       'windspeedMiles': '14',
#       'windspeedKmph': '23',
#       'winddirDegree': '327',
#       'winddir16Point': 'NNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '62',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1017',
#       'pressureInches': '31',
#       'cloudcover': '6',
#       'HeatIndexC': '9',
#       'HeatIndexF': '49',
#       'DewPointC': '3',
#       'DewPointF': '37',
#       'WindChillC': '6',
#       'WindChillF': '44',
#       'WindGustMiles': '18',
#       'WindGustKmph': '29',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '44',
#       'uvIndex': '1'},
#      {'time': '300',
#       'tempC': '6',
#       'tempF': '42',
#       'windspeedMiles': '12',
#       'windspeedKmph': '20',
#       'winddirDegree': '329',
#       'winddir16Point': 'NNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '64',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '6',
#       'HeatIndexF': '42',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '600',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '11',
#       'windspeedKmph': '17',
#       'winddirDegree': '324',
#       'winddir16Point': 'NW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '68',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '1',
#       'WindChillF': '33',
#       'WindGustMiles': '14',
#       'WindGustKmph': '23',
#       'FeelsLikeC': '1',
#       'FeelsLikeF': '33',
#       'uvIndex': '1'},
#      {'time': '900',
#       'tempC': '6',
#       'tempF': '42',
#       'windspeedMiles': '10',
#       'windspeedKmph': '17',
#       'winddirDegree': '319',
#       'winddir16Point': 'NW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '64',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '6',
#       'HeatIndexF': '42',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '3'},
#      {'time': '1200',
#       'tempC': '11',
#       'tempF': '52',
#       'windspeedMiles': '12',
#       'windspeedKmph': '19',
#       'winddirDegree': '312',
#       'winddir16Point': 'NW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '43',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '11',
#       'HeatIndexF': '52',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '9',
#       'WindChillF': '49',
#       'WindGustMiles': '13',
#       'WindGustKmph': '22',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '49',
#       'uvIndex': '4'},
#      {'time': '1500',
#       'tempC': '16',
#       'tempF': '61',
#       'windspeedMiles': '13',
#       'windspeedKmph': '20',
#       'winddirDegree': '304',
#       'winddir16Point': 'WNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '33',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '16',
#       'HeatIndexF': '61',
#       'DewPointC': '-0',
#       'DewPointF': '32',
#       'WindChillC': '16',
#       'WindChillF': '61',
#       'WindGustMiles': '15',
#       'WindGustKmph': '23',
#       'FeelsLikeC': '16',
#       'FeelsLikeF': '61',
#       'uvIndex': '5'},
#      {'time': '1800',
#       'tempC': '16',
#       'tempF': '62',
#       'windspeedMiles': '12',
#       'windspeedKmph': '20',
#       'winddirDegree': '302',
#       'winddir16Point': 'WNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '37',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1017',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '16',
#       'HeatIndexF': '62',
#       'DewPointC': '2',
#       'DewPointF': '35',
#       'WindChillC': '16',
#       'WindChillF': '61',
#       'WindGustMiles': '15',
#       'WindGustKmph': '25',
#       'FeelsLikeC': '16',
#       'FeelsLikeF': '61',
#       'uvIndex': '5'},
#      {'time': '2100',
#       'tempC': '14',
#       'tempF': '57',
#       'windspeedMiles': '10',
#       'windspeedKmph': '16',
#       'winddirDegree': '301',
#       'winddir16Point': 'WNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '50',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '31',
#       'cloudcover': '0',
#       'HeatIndexC': '14',
#       'HeatIndexF': '57',
#       'DewPointC': '4',
#       'DewPointF': '38',
#       'WindChillC': '13',
#       'WindChillF': '55',
#       'WindGustMiles': '15',
#       'WindGustKmph': '25',
#       'FeelsLikeC': '13',
#       'FeelsLikeF': '55',
#       'uvIndex': '1'}]}]}}
